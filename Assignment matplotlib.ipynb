# %%
'''Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of
Matplotlib.

matplotlib is comprehensive library for creating static, animated and interactive visualization in python. 
It is one of the most popular python libraries for data visualization.

Using matplotlib we can plot following plots
1. Histogram
2. Scatter plot
3. Pie chart
4. Box Plot
5. 3D Plot'''
# Out:
# 'Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of\nMatplotlib.\n\nmatplotlib is comprehensive library for creating static, animated and interactive visualization in python. \nIt is one of the most popular python libraries for data visualization.\n\nUsing matplotlib we can plot following plots\n1. Histogram\n2. Scatter plot\n3. Pie chart\n4. Box Plot\n5. 3D Plot'

# %%
'''Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data
plot a scatter plot.
import numpy as np
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))

Scatter plot is dot plot between x and y.
'''
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))

plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.title("Scatter Plot")
plt.scatter(x,y)

# %%
'''Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.
Use the following data:
import numpy as np
For line 1: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([0, 100, 200, 300, 400, 500])
For line 2: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([50, 20, 40, 20, 60, 70])
For line 3: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([10, 20, 30, 40, 50, 60])
For line 4: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([200, 350, 250, 550, 450, 150])

The subplot() function in Matplotlib is used to create a figure and a set of subplots. It is a convenient 
way to create common layouts of subplots, including the enclosing figure object, in a single call.
'''
x = np.array([0, 1, 2, 3, 4, 5])

fig , axs = plt.subplots(2,2)

axs[0,0].plot(x,np.array([0, 100, 200, 300, 400, 500]))
axs[0,0].set_title("First Plot")

axs[0,1].plot(x,np.array([50, 20, 40, 20, 60, 70]))
axs[0,1].set_title("Second Plot")

axs[1,0].plot(x,np.array([10, 20, 30, 40, 50, 60]))
axs[1,0].set_title("Third Plot")
             
axs[1,1].plot(x,np.array([200, 350, 250, 550, 450, 150]))
axs[1,1].set_title("Fourth Plot")

fig.suptitle("Four Plots")
plt.tight_layout()

# %%
'''Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.
import numpy as np
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])


 A bar plot is a type of data visualization that uses rectangular bars to represent categorical data. 
 The height or length of each bar is proportional to the value of the corresponding category. 
 Bar plots can be used to show the distribution of data, compare different categories, or track changes over time.

Bar plots are commonly used in a variety of fields, including business, science, and education. 
For example, a bar plot might be used to show the sales of different products in a store, the number 
of students in each grade level at a school, or the average temperature in each month of the year.'''

company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

plt.barh(company,profit)
# Out:
# <BarContainer object of 4 artists>

# %%
'''Q5: What is a box plot? Why is it used? Using the following data plot a box plot.
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)


A boxplot is a simple way to visualize the distribution of a set of data. it shows the central
tendancy , spread and skewnessof the data.
'''
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)

plt.boxplot(box1)
plt.boxplot(box2)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x20f0fa00be0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x20f0fa01120>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x20f0fa00940>],
#  'medians': [<matplotlib.lines.Line2D at 0x20f0fa01660>],
#  'fliers': [<matplotlib.lines.Line2D at 0x20f0fa01900>],
#  'means': []}
